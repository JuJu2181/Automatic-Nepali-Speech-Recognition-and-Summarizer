# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/JuJu2181/Automatic-Nepali-Speech-Recognition-and-Summarizer
# Out:
# Cloning into 'Automatic-Nepali-Speech-Recognition-and-Summarizer'...
# remote: Enumerating objects: 464, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 464 (delta 5), reused 12 (delta 4), pack-reused 441
# Receiving objects: 100% (464/464), 112.91 MiB | 12.55 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# Checking out files: 100% (318/318), done.

# %%
# %cd /content
# Out:
# /content

# %%
# !mkdir ~/.kaggle 
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json 
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download anishshilpakar/asr-cnn-dataset
# Out:
# ...
# 100% 6.84G/6.87G [00:57<00:00, 121MB/s]
# 100% 6.87G/6.87G [00:57<00:00, 129MB/s]

# %%
file_path = '/content/asr-cnn-dataset.zip'
dest_path = '/content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr'

# %%
# !unzip $file_path -d $dest_path
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fadf45b4f7.flac
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fadf5d7ae0.flac
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fadf85cf0e.flac
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fae1b9367c.flac
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fae2158390.flac
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fae3e16c4e.flac
#   inflating: /content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio/fae43b6d65.flac
# ...

# %%
import os 
len(os.listdir('/content/drive/MyDrive/Automatic-Nepali-Speech-Recognition-and-Summarizer/ASR/data_asr/audio/audio'))
# Out:
# 142695

# %%
drive.flush_and_unmount()
