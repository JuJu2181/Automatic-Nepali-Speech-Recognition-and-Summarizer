# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/ASR/ASR
# Out:
# /content/gdrive/MyDrive/ASR/ASR

# %%
# !pip install datasets
# !pip install transformers
# !pip install torchaudio
# !pip install librosa
# !pip install jiwer
# !pip install wandb
# Out:
# Requirement already satisfied: datasets in d:\programming\python\.aivenv\lib\site-packages (2.4.0)
# Requirement already satisfied: packaging in d:\programming\python\.aivenv\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: aiohttp in d:\programming\python\.aivenv\lib\site-packages (from datasets) (3.8.1)
# Requirement already satisfied: multiprocess in d:\programming\python\.aivenv\lib\site-packages (from datasets) (0.70.13)
# Requirement already satisfied: responses<0.19 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: dill<0.3.6 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (2.27.1)
# Requirement already satisfied: pyarrow>=6.0.0 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (8.0.0)
# Requirement already satisfied: pandas in d:\programming\python\.aivenv\lib\site-packages (from datasets) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (1.22.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (0.8.1)
# Requirement already satisfied: xxhash in d:\programming\python\.aivenv\lib\site-packages (from datasets) (3.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (4.64.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in d:\programming\python\.aivenv\lib\site-packages (from datasets) (2022.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\programming\python\.aivenv\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\programming\python\.aivenv\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in d:\programming\python\.aivenv\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\programming\python\.aivenv\lib\site-packages (from packaging->datasets) (3.0.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->datasets) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: colorama in d:\programming\python\.aivenv\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\programming\python\.aivenv\lib\site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\programming\python\.aivenv\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\programming\python\.aivenv\lib\site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\programming\python\.aivenv\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\programming\python\.aivenv\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\programming\python\.aivenv\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\programming\python\.aivenv\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\programming\python\.aivenv\lib\site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in d:\programming\python\.aivenv\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# Requirement already satisfied: transformers in d:\programming\python\.aivenv\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.17 in d:\programming\python\.aivenv\lib\site-packages (from transformers) (1.22.0)
# Requirement already satisfied: filelock in d:\programming\python\.aivenv\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: sacremoses in d:\programming\python\.aivenv\lib\site-packages (from transformers) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in d:\programming\python\.aivenv\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: requests in d:\programming\python\.aivenv\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in d:\programming\python\.aivenv\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in d:\programming\python\.aivenv\lib\site-packages (from transformers) (2022.4.24)
# Requirement already satisfied: packaging in d:\programming\python\.aivenv\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: colorama in d:\programming\python\.aivenv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\programming\python\.aivenv\lib\site-packages (from packaging->transformers) (3.0.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\python\.aivenv\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programming\python\.aivenv\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\python\.aivenv\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programming\python\.aivenv\lib\site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: six in d:\programming\python\.aivenv\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: joblib in d:\programming\python\.aivenv\lib\site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in d:\programming\python\.aivenv\lib\site-packages (from sacremoses->transformers) (8.1.3)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# Requirement already satisfied: torchaudio in d:\programming\python\.aivenv\lib\site-packages (0.12.0)
# Requirement already satisfied: torch==1.12.0 in d:\programming\python\.aivenv\lib\site-packages (from torchaudio) (1.12.0)
# Requirement already satisfied: typing-extensions in d:\programming\python\.aivenv\lib\site-packages (from torch==1.12.0->torchaudio) (4.2.0)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# Requirement already satisfied: librosa in d:\programming\python\.aivenv\lib\site-packages (0.9.2)
# Requirement already satisfied: pooch>=1.0 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (0.3.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (1.1.1)
# Requirement already satisfied: numba>=0.45.1 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (0.56.0)
# Requirement already satisfied: decorator>=4.0.10 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: audioread>=2.1.9 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: soundfile>=0.10.2 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (21.3)
# Requirement already satisfied: numpy>=1.17.0 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (1.22.0)
# Requirement already satisfied: scipy>=1.2.0 in d:\programming\python\.aivenv\lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: setuptools in d:\programming\python\.aivenv\lib\site-packages (from numba>=0.45.1->librosa) (60.9.3)
# Requirement already satisfied: importlib-metadata in d:\programming\python\.aivenv\lib\site-packages (from numba>=0.45.1->librosa) (4.11.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in d:\programming\python\.aivenv\lib\site-packages (from numba>=0.45.1->librosa) (0.39.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\programming\python\.aivenv\lib\site-packages (from packaging>=20.0->librosa) (3.0.8)
# Requirement already satisfied: requests>=2.19.0 in d:\programming\python\.aivenv\lib\site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in d:\programming\python\.aivenv\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programming\python\.aivenv\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in d:\programming\python\.aivenv\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in d:\programming\python\.aivenv\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programming\python\.aivenv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: zipp>=0.5 in d:\programming\python\.aivenv\lib\site-packages (from importlib-metadata->numba>=0.45.1->librosa) (3.8.0)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp38-cp38-win_amd64.whl (182 kB)
#      -------------------------------------- 182.7/182.7 kB 1.6 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.11.1-cp38-cp38-win_amd64.whl (994 kB)
#      -------------------------------------- 994.8/994.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein, jiwer
# Successfully installed jiwer-2.5.1 levenshtein-0.20.2 rapidfuzz-2.11.1
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# Requirement already satisfied: wandb in d:\programming\python\.aivenv\lib\site-packages (0.12.19)
# Requirement already satisfied: PyYAML in d:\programming\python\.aivenv\lib\site-packages (from wandb) (6.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (1.6.0)
# Requirement already satisfied: GitPython>=1.0.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (3.1.27)
# Requirement already satisfied: setproctitle in d:\programming\python\.aivenv\lib\site-packages (from wandb) (1.2.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (8.1.3)
# Requirement already satisfied: six>=1.13.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (1.16.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (3.20.1)
# Requirement already satisfied: requests<3,>=2.0.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (2.27.1)
# Requirement already satisfied: setuptools in d:\programming\python\.aivenv\lib\site-packages (from wandb) (60.9.3)
# Requirement already satisfied: psutil>=5.0.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (5.9.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: promise<3,>=2.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in d:\programming\python\.aivenv\lib\site-packages (from wandb) (1.0.9)
# Requirement already satisfied: pathtools in d:\programming\python\.aivenv\lib\site-packages (from wandb) (0.1.2)
# Requirement already satisfied: colorama in d:\programming\python\.aivenv\lib\site-packages (from Click!=8.0.0,>=7.0->wandb) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\programming\python\.aivenv\lib\site-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\python\.aivenv\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programming\python\.aivenv\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\python\.aivenv\lib\site-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programming\python\.aivenv\lib\site-packages (from requests<3,>=2.0.0->wandb) (1.26.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\programming\python\.aivenv\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programming\python\.aivenv\lib\site-packages)

# %%
from datasets import Audio, ClassLabel, load_dataset, load_metric
from IPython.display import display, HTML
from sklearn.model_selection import train_test_split
from torch._C import device
from transformers import (
    EarlyStoppingCallback,
    Trainer,
    TrainingArguments,
    Wav2Vec2CTCTokenizer,
    Wav2Vec2FeatureExtractor,
    Wav2Vec2ForCTC,
    Wav2Vec2Processor,
    trainer_utils
)

# %%
import json
import os
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

import IPython.display as ipd
import jiwer
import librosa
import numpy as np
import pandas as pd
import random
import re
import torch
import torch.functional as F
import torch.nn as nn
import torch.optim as optim
import torchaudio
import wandb
# from datasets import Audio, ClassLabel, load_dataset, load_metric
# from IPython.display import display, HTML
# from sklearn.model_selection import train_test_split
# from torch._C import device
# from torch.utils.data import Dataset
# from transformers import (
#     EarlyStoppingCallback,
#     Trainer,
#     TrainingArguments,
#     Wav2Vec2CTCTokenizer,
#     Wav2Vec2FeatureExtractor,
#     Wav2Vec2ForCTC,
#     Wav2Vec2Processor,
#     trainer_utils
# )

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
WANDB_KEY = os.getenv('WANDB_KEY')

# %%
wandb.login(key=WANDB_KEY) # add wandb API key
wandb.init(project="speech")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: anish_shilpakar. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\dell/.netrc
# wandb version 0.13.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>d:\Programming\Projects\major_project\Codes\ASR\notebooks\wandb\run-20221017_132431-1srf4x2w</code>
# Syncing run <strong><a href="https://wandb.ai/anish_shilpakar/speech/runs/1srf4x2w" target="_blank">playful-firefly-3</a></strong> to <a href="https://wandb.ai/anish_shilpakar/speech" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/anish_shilpakar/speech/runs/1srf4x2w?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
import os

# os.mkdir("/kaggle/working/ne_np_female/")

# %%
# colnames = ["path", "labels"] 
# df_tsv = pd.read_csv('/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript/line_index.tsv', sep = "\t", header = None, names = colnames)
# df_tsv.to_csv('/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript/ne_np_female.csv', index=False)

# df_openslr = pd.read_csv('/content/gdrive/MyDrive/ASR/ASR/data/transcript/dataset_v2.csv')
# df_openslr = df_openslr[["filename","text"]]
# df_openslr.head()
# df_openslr.to_csv('/content/gdrive/MyDrive/ASR/ASR/data/transcript/dataset_v3.csv', index=False)

# %%
colnames = ["path", "labels"] 
transcript_path_ne_np = '/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript/ne_np_female.csv'
audio_path_ne_np = '/content/gdrive/MyDrive/ASR/ASR/ne_np_female/audio/'
transcript_path_openslr = '/content/gdrive/MyDrive/ASR/ASR/data/transcript/dataset_v3.csv'
audio_path_openslr = '/content/gdrive/MyDrive/ASR/ASR/data/audio/'
df = pd.read_csv(transcript_path_ne_np)
df.rename(columns={"filename": "path","text":'labels'}, inplace=True)
# df["path"] = audio_path_openslr + df["path"] + ".flac"
df["path"] = audio_path_ne_np + df["path"] + ".wav"
df.head()
# Out:
#                                                 path  \
# 0  /content/gdrive/MyDrive/ASR/ASR/ne_np_female/a...
# 1  /content/gdrive/MyDrive/ASR/ASR/ne_np_female/a...
# 2  /content/gdrive/MyDrive/ASR/ASR/ne_np_female/a...
# 3  /content/gdrive/MyDrive/ASR/ASR/ne_np_female/a...
# 4  /content/gdrive/MyDrive/ASR/ASR/ne_np_female/a...
#
#                                               labels
# 0  दीपा धामीको जन्म सुदूरपश्चिम नेपालको बझाङ जिल्...
# 1  डिग्रा देवीको जन्म सुदूरपश्चिम नेपालको बझाङ जि...
# 2  टेकबहादुर ऐरको जन्म सुदूरपश्चिम नेपालको डडेलधु...
# 3  सुमन शेखरमानन्धर नेपालको कृषि अर्थविद् तथा गाय...
# 4  आधिकारिक रूपमा पहिलो नेपाली चलचित्र नायक शिव श...

# %%
train_df, test_df = train_test_split(df, random_state = 0, train_size = .80)
train_df, val_df = train_test_split(df, random_state = 0, train_size = .75)

# %%
# %cd /content/gdrive/MyDrive/ASR/ASR
# Out:
# /content/gdrive/MyDrive/ASR/ASR

# %%
train_df.to_csv("/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript/train_ne_np_female.csv", index = False)
val_df.to_csv("/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript/val_ne_np_female.csv", index = False)
test_df.to_csv("/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript/test_ne_np_female.csv", index = False)

# %%
data_files = {
    "train": "train_ne_np_female.csv",
    "validation": "val_ne_np_female.csv",
    "test": "test_ne_np_female.csv"
}

# %%
train_data = load_dataset("/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript", data_files = data_files, split = "train")
val_data = load_dataset("/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript", data_files = data_files, split = "validation")
# Out:
# WARNING:datasets.builder:Using custom data configuration transcript-a77a3cc2759a1c11
# Downloading and preparing dataset csv/transcript to /root/.cache/huggingface/datasets/csv/transcript-a77a3cc2759a1c11/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# WARNING:datasets.builder:Using custom data configuration transcript-a77a3cc2759a1c11
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/transcript-a77a3cc2759a1c11/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/transcript-a77a3cc2759a1c11/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.

# %%
def show_random_elements(dataset, num_examples = 10):
    assert num_examples <=  len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(train_data.remove_columns(["path"]), num_examples = 20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>शङ्कर सिंह बिस्टको जन्म सुदूरपश्चिम नेपालको दार्चुला जिल्लामा भएको हो</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>क्युबेकको रिमाउस्कीमा रहेको सहर को जिल्ला</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>अन्तर्राष्ट्रिय आइस हकी प्रतियोगिता</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>आइस हकी च्याम्पियनसिप</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>पञ्चकन्या शहीदस्मृति पार्क धनकुटा जिल्लामा अवस्थित एउटा स्मृति पार्क</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>मिसिगनमा अन्तरराज्यीय राजमार्ग</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>माछापु्च्छ्रे र फेवातालको प्रतिविम्ब जिल्ला पर्यटन व्यवसायका रथी हुन्</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>मैले चेज क्यारोलिनको बारेमा धेरै पहिले सुनेको थिएँ तर यहाँ कहिल्यै आएको थिइनँ</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>महेन्द्र बिक देउडा गीति एल्बमहरूको सम्पादन कार्य गर्ने गर्दथे</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>पोखराको फेवा ताल आसपासको क्षेत्रमा यो वनस्पति प्रशस्त मात्रामा पाइन्छ</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>नविल बैङ्क लिमिटेड नेपाल राष्ट्र बैँकबाट इजाजत प्राप्त बैङ्क हो</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>चितवन राष्ट्रिय निकुञ्जमा हात्ती पोलो वार्षिक रूपमा आयोजना गरिन्छ</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>पत्रिकाको सम्पादन कार्य विष्णुकुमारी लिम्बुद्वारा भएको</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>तेइसौँ जेम्स बन्ड फिलिम</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>मुस्ताङ हिमाली जिल्ला हो</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>यो गाविस उत्तर दक्षिणतर्फ जोगमाई नदीसम्म फैलिएको छ</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>उत्तर कोरियाको सबैभन्दा घनिष्ट सम्वन्ध चीनले किमको निधनमा गहिरो दुःख व्यक्त गरेको छ</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>सोही दिन आफ्ना नातागोतालाई घरमा डाक्ने र खुवाउने परम्परा रहेको छ</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>भक्तपुर क्यान्सर अस्पतालले दक्षिण एसियाका सेवाग्राहीहरूलाई सेवा प्रदान गर्दछ</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>पश्चिम नेपालको बैतडीस्थित यो सडकको नाम दशरथ चन्द राजमार्ग राखिएको छ</td>
#     </tr>
#   </tbody>
# </table>

# %%
chars_to_ignore = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�]'

def remove_special_characters(batch):
    batch["labels"] = re.sub(chars_to_ignore, '', batch["labels"]).lower() + " "
    return batch

# %%
train_data = train_data.map(remove_special_characters)
val_data = val_data.map(remove_special_characters)
# Out:
#   0%|          | 0/1548 [00:00<?, ?ex/s]
#   0%|          | 0/516 [00:00<?, ?ex/s]

# %%
show_random_elements(train_data.remove_columns(["path"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>गायक दिपक सगंम सुदुर पश्चिमेली साङ्गीतिक क्षेत्रका महान् व्यक्ति हुन्</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ब्रोड शिखर वा के तीन पाकिस्तान र चीनको सिमानामा अवस्थित विश्वको बाह्रौँ अग्लो हिमाल हो</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>फ्रान्सेली गणतन्त्रको एक्काइसौँ राष्ट्रपति</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ललित बोहराको जन्म सुदूरपश्चिम नेपालको बाजुरा जिल्लामा भएको हो</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>एन्ड्रयू मिलरद्वारा रचित उपन्यास</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>नक्षत्र उरसा मेजरमा स्पाइरल आकासगङ्गा</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>तानसेन तम्घास सडक एउटा पहाडी क्षेत्रमा निर्मित सडक हो</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>प्लानेटरी मास वस्तु</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>यो चर्चित नायिका झरना बज्राचार्यले अभिनय गरेको एउटा नेपाली चलचित्र हो</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>जर्मनीको सक्सोनीमा रहेको गाउँ</td>
#     </tr>
#   </tbody>
# </table>

# %%
vocab_path = '/content/gdrive/MyDrive/ASR/ASR/data/vocab.json'
tokenizer = Wav2Vec2CTCTokenizer(
    vocab_path, 
    unk_token = "[UNK]", 
    pad_token = "[PAD]", 
    word_delimiter_token = "|"
)

# %%
feature_extractor = Wav2Vec2FeatureExtractor(
    feature_size = 1, 
    sampling_rate = 16000, 
    padding_value = 0.0, 
    do_normalize = True, 
    return_attention_mask = True
)

# %%
processor = Wav2Vec2Processor(
    feature_extractor = feature_extractor, 
    tokenizer = tokenizer
)

# %%
processor.save_pretrained("/content/gdrive/MyDrive/ASR/ASR/processor")

# %%
train_data[0]
# Out:
# {'path': '/content/gdrive/MyDrive/ASR/ASR/ne_np_female/audio/nep_5687_6685827002.wav',
#  'labels': 'नमोबुद्ध कस्मेटिक एण्ड टेलरिङ्ग सेन्टरबाट सिलाइएका लुगाहरू मिलेका र राम्रा हुन्छन् '}

# %%
val_data
# Out:
# Dataset({
#     features: ['path', 'labels'],
#     num_rows: 516
# })

# %%
def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["labels"]
    
    resampler = torchaudio.transforms.Resample(sampling_rate, 16000)
    batch["speech"] = resampler(speech_array).squeeze().numpy()
    batch["sampling_rate"] = 16000
    
    return batch

# %%
train_data = train_data.map(speech_file_to_array_fn, remove_columns=train_data.column_names)
val_data = val_data.map(speech_file_to_array_fn, remove_columns=val_data.column_names)
# Out:
#   0%|          | 0/1548 [00:00<?, ?ex/s]
#   0%|          | 0/516 [00:00<?, ?ex/s]

# %%
# def resample(batch):
#     batch["speech"] = librosa.resample(np.asarray(batch["speech"]), batch["sampling_rate"], 16000)
#     batch["sampling_rate"] = 16000
#     return batch

# %%
# train_data = train_data.map(resample, num_proc=4)
# val_data = val_data.map(resample, num_proc=4)

# %%
rand_int = random.randint(0, len(train_data) - 1)
ipd.Audio(data = np.asarray(
    train_data[rand_int]["speech"]), 
    autoplay = True, 
    rate = 16000
)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_int = random.randint(0, len(train_data) - 1)

print("Target text:", train_data[rand_int]["target_text"])
print("Input array shape:", np.asarray(train_data[rand_int]["speech"]).shape)
print("Sampling rate:", train_data[rand_int]["sampling_rate"])
# Out:
# Target text: जापानी कलाकार युकियोए चित्रकार र प्रिन्टमेकर
# Input array shape: (68512,)
# Sampling rate: 16000

# %%
def prepare_dataset(batch, processor):
        
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate = batch["sampling_rate"][0]).input_values

    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

# %%
train_data = train_data.map(prepare_dataset, fn_kwargs = {"processor": processor}, remove_columns = train_data.column_names, batch_size = 8, num_proc = 4, batched = True)
val_data = val_data.map(prepare_dataset, fn_kwargs = {"processor": processor}, remove_columns = val_data.column_names, batch_size = 8, num_proc = 4, batched = True)
# Out:
# #0:   0%|          | 0/49 [00:00<?, ?ba/s]
# #1:   0%|          | 0/49 [00:00<?, ?ba/s]
# #3:   0%|          | 0/49 [00:00<?, ?ba/s]
# #2:   0%|          | 0/49 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# #0:   0%|          | 0/17 [00:00<?, ?ba/s]
# #2:   0%|          | 0/17 [00:00<?, ?ba/s]
# #1:   0%|          | 0/17 [00:00<?, ?ba/s]
# #3:   0%|          | 0/17 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# /usr/local/lib/python3.7/dist-packages/transformers/feature_extraction_utils.py:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "

# %%
@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor = processor, padding = True)

# %%
wer_metric = load_metric("wer")
cer_metric = load_metric("cer", revision = "master")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   """Entry point for launching an IPython kernel.
# Downloading builder script:   0%|          | 0.00/1.90k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)
    cer = cer_metric.compute(predictions=pred_str, references=label_str)
    
    # cer_best = 1 - cer because load best model is considering greater value of cer for better results
    cer_best = 1 - cer
    # wandb.log({'wer':wer, 'cer':cer})
    # experiment.log_metric('wer', wer)
    # experiment.log_metric('cer', cer)
    
    return {"wer": wer, "cer": cer, "cer_best": cer_best}

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53", 
    attention_dropout = 0.1,
    hidden_dropout = 0.1,
    feat_proj_dropout = 0.0,
    mask_time_prob = 0.05,
    layerdrop = 0.1,
    gradient_checkpointing = True, 
    ctc_loss_reduction = "mean", 
    pad_token_id = processor.tokenizer.pad_token_id,
    vocab_size = len(processor.tokenizer)
)
# Out:
# Downloading:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2ForCTC: ['quantizer.codevectors', 'project_hid.weight', 'quantizer.weight_proj.bias', 'project_q.weight', 'project_q.bias', 'quantizer.weight_proj.weight', 'project_hid.bias']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:1638: FutureWarning: The method `freeze_feature_extractor` is deprecated and will be removed in Transformers v5.Please use the equivalent `freeze_feature_encoder` method instead.
#   FutureWarning,

# %%
training_args = TrainingArguments(
  output_dir = "/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models",
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16 = True,
  save_steps = 144,
  eval_steps=144,
  logging_steps=144,
  learning_rate=3e-4,
  warmup_steps=180,
  save_total_limit = 2,
  overwrite_output_dir=True,
  gradient_checkpointing = True,
  report_to = "wandb",
  metric_for_best_model = 'cer_best',
  load_best_model_at_end=True
)

# %%
import tensorflow as tf
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %%
# !nvidia-smi
# Out:
# Sat Oct 15 07:07:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
trainer = Trainer(
    model = model,
    data_collator = data_collator,
    args = training_args,
    compute_metrics = compute_metrics,
    train_dataset = train_data,
    eval_dataset = val_data,
    tokenizer = processor.feature_extractor,
)
# Out:
# Using cuda_amp half precision backend

# %%
train_data
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 1548
# })

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1548
#   Num Epochs = 30
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 2
#   Total optimization steps = 1440
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
#     <div>
#
#       <progress value='1440' max='1440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1440/1440 1:40:30, Epoch 29/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#       <th>Cer</th>
#       <th>Cer Best</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>144</td>
#       <td>6.911300</td>
#       <td>3.403597</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>288</td>
#       <td>3.397300</td>
#       <td>3.130925</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>432</td>
#       <td>1.678800</td>
#       <td>0.624511</td>
#       <td>0.694419</td>
#       <td>0.177321</td>
#       <td>0.822679</td>
#     </tr>
#     <tr>
#       <td>576</td>
#       <td>0.619400</td>
#       <td>0.407999</td>
#       <td>0.498425</td>
#       <td>0.111445</td>
#       <td>0.888555</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.422300</td>
#       <td>0.354512</td>
#       <td>0.458371</td>
#       <td>0.109131</td>
#       <td>0.890869</td>
#     </tr>
#     <tr>
#       <td>864</td>
#       <td>0.309800</td>
#       <td>0.340006</td>
#       <td>0.408866</td>
#       <td>0.093158</td>
#       <td>0.906842</td>
#     </tr>
#     <tr>
#       <td>1008</td>
#       <td>0.239200</td>
#       <td>0.333810</td>
#       <td>0.367012</td>
#       <td>0.079302</td>
#       <td>0.920698</td>
#     </tr>
#     <tr>
#       <td>1152</td>
#       <td>0.209000</td>
#       <td>0.326797</td>
#       <td>0.366112</td>
#       <td>0.080426</td>
#       <td>0.919574</td>
#     </tr>
#     <tr>
#       <td>1296</td>
#       <td>0.186600</td>
#       <td>0.328846</td>
#       <td>0.358911</td>
#       <td>0.080360</td>
#       <td>0.919640</td>
#     </tr>
#     <tr>
#       <td>1440</td>
#       <td>0.168300</td>
#       <td>0.330840</td>
#       <td>0.353960</td>
#       <td>0.078409</td>
#       <td>0.921591</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-144
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-144/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-144/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-144/preprocessor_config.json
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-288
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-288/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-288/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-288/preprocessor_config.json
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-432
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-432/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-432/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-432/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-144] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-576
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-576/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-576/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-576/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-288] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-720
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-720/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-720/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-720/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-432] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-864
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-864/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-864/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-864/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-576] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1008
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1008/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1008/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1008/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-720] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1152
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1152/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1152/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1152/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-864] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1296
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1296/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1296/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1296/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1152] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:155: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   "`as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your "
# ***** Running Evaluation *****
#   Num examples = 516
#   Batch size = 8
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1440
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1440/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1440/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1440/preprocessor_config.json
# Deleting older checkpoint [/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1008] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/checkpoint-1440 (score: 0.9215913224643673).
# TrainOutput(global_step=1440, training_loss=1.4141920222176445, metrics={'train_runtime': 6045.921, 'train_samples_per_second': 7.681, 'train_steps_per_second': 0.238, 'total_flos': 7.200087718487112e+18, 'train_loss': 1.4141920222176445, 'epoch': 29.99})

# %%
trainer.save_model("/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models")
# Out:
# Saving model checkpoint to /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models
# Configuration saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/config.json
# Model weights saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/pytorch_model.bin
# Feature extractor saved in /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/preprocessor_config.json

# %% [markdown]
# test

# %%
model = Wav2Vec2ForCTC.from_pretrained("/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/model_ne_np_femalev1").to("cuda")
processor = Wav2Vec2Processor.from_pretrained("/content/gdrive/MyDrive/ASR/ASR/processor")
# Out:
# loading configuration file /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/model_ne_np_femalev1/config.json
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-large-xlsr-53",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 768,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": true,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": false,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": true,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_dropout": 0.0,
#   "feat_extract_norm": "layer",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "num_adapter_layers": 3,
#   "num_attention_heads": 16,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 24,
#   "num_negatives": 100,
#   "output_hidden_size": 1024,
#   "pad_token_id": 78,
#   "proj_codevector_dim": 768,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 79,
#   "xvector_output_dim": 512
# }
#
# loading weights file /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/model_ne_np_femalev1/pytorch_model.bin
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at /content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/model_ne_np_femalev1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.
# loading configuration file /content/gdrive/MyDrive/ASR/ASR/processor/preprocessor_config.json
# Feature extractor Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "Wav2Vec2Processor",
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }
#
# loading file vocab.json
# loading file tokenizer_config.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# Adding <s> to the vocabulary
# Adding </s> to the vocabulary
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
input_dict = processor(val_data["input_values"][0], return_tensors = "pt", padding = True)

logits = model(input_dict.input_values.to("cuda")).logits
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.

# %%
pred_ids = torch.argmax(logits, dim = -1)[0]

# %%
test_transcription_data = load_dataset("/content/gdrive/MyDrive/ASR/ASR/ne_np_female/transcript", data_files = data_files, split = "test")
# Out:
# WARNING:datasets.builder:Using custom data configuration transcript-a77a3cc2759a1c11
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/transcript-a77a3cc2759a1c11/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)

# %%
print("Prediction:")
print(processor.decode(pred_ids))

print("\nReference:")
print(test_transcription_data["labels"][0].lower())
# Out:
# Prediction:
# कालोटाउके गङगा चील नेपालमा पाइने एक प्रकारको चराको नाम हो
#
# Reference:
# कालोटाउके गंगाचील नेपालमा पाइने एक प्रकारको चराको नाम हो

# %%
input_dict = processor(val_data["input_values"][3], return_tensors = "pt", padding = True)
print(input_dict)

logits = model(input_dict.input_values.to("cuda")).logits
print(logits)
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# {'input_values': tensor([[0.0008, 0.0008, 0.0008,  ..., 0.0008, 0.0008, 0.0008]]), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]], dtype=torch.int32)}
# tensor([[[-0.4658, -0.3296, -2.9032,  ..., -0.7714, -6.8592, 12.2530],
#          [-0.4680, -0.3152, -2.9366,  ..., -0.8317, -6.8732, 12.3143],
#          [-0.4648, -0.2898, -2.9039,  ..., -0.8486, -6.8883, 12.3328],
#          ...,
#          [ 0.3744, -0.3150, -2.8307,  ..., -1.0509, -6.9534, 12.4945],
#          [ 1.5442, -0.6042, -2.9129,  ..., -1.1653, -6.9635, 12.4679],
#          [11.0722, -0.3818, -1.5613,  ..., -1.8593, -3.2529,  4.2605]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)

# %%
pred_ids = torch.argmax(logits, dim = -1)[0]

# %%
print("Prediction:")
print(processor.decode(pred_ids))

print("\nReference:")
print(test_transcription_data["labels"][3].lower())
# Out:
# Prediction:
# फेसन पारखी उनिफेसनकोक्षेत्रमा एक आइकन थिए
#
# Reference:
# फेसन पारखी उनी फेसनको क्षेत्रमा एक आइकन थिए

# %% [markdown]
# Load model

# %%
# model = Wav2Vec2ForCTC.from_pretrained("/content/gdrive/MyDrive/ASR/ASR/wav2vec_trained_models/model_ne_np_femalev1").to("cuda")
# processor = Wav2Vec2Processor.from_pretrained("/content/gdrive/MyDrive/ASR/ASR/processor")
model = Wav2Vec2ForCTC.from_pretrained("../wav2vec_trained_models/model_ne_np_femalev1").to("cpu")
processor = Wav2Vec2Processor.from_pretrained("../processor")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.

# %%
# test_audio_ip1 = '/content/gdrive/MyDrive/ASR/ASR/ne_np_female/rec3.wav'
# test_audio_ip2 = '/content/gdrive/MyDrive/ASR/ASR/ne_np_female/audio/nep_0258_0119737288.wav'
test_audio_ip1 = '../ne_np_female/rec3.wav'
test_audio_ip2 = '../ne_np_female/test1_anjan.wav'
test_audio_ip3 = '../ne_np_female/testy.flac'

# %%
def predict_from_speech(file):
    speech_array, sampling_rate = torchaudio.load(file)
    print(speech_array,sampling_rate)
    resampler = torchaudio.transforms.Resample(sampling_rate, 16000)
    resampled_array = resampler(speech_array).squeeze()
    if len(resampled_array.shape) == 1:
        resampled_array = resampled_array.reshape([1,resampled_array.shape[0]])
    # print(resampled_array)
    # print(resampled_array.shape)
    logits = model(resampled_array.to("cpu")).logits
    # print(logits)
    pred_ids = torch.argmax(logits, dim = -1)[0]
    print("Prediction:")
    print(processor.decode(pred_ids))

# %%
predict_from_speech(test_audio_ip1)
predict_from_speech(test_audio_ip2)
# Out:
# tensor([[ 2.4414e-04,  3.0518e-04,  2.7466e-04,  ...,  2.4414e-04,
#           1.8311e-04,  0.0000e+00],
#         [ 2.4414e-04,  2.7466e-04,  2.1362e-04,  ...,  2.4414e-04,
#           2.4414e-04, -9.1553e-05]]) 44100
# Prediction:
# नेपालीमा टाइप कर्ने सबैभण्डा सजिलो र छितो तरेकर
# tensor([[ 6.1035e-05, -3.0518e-05, -3.0518e-05,  ...,  6.1035e-05,
#          -1.5259e-04,  9.1553e-05],
#         [ 3.0518e-05,  3.0518e-05,  3.0518e-05,  ..., -3.0518e-05,
#          -3.0518e-05, -6.1035e-05]]) 44100
# Prediction:
# इत्तरमा चुरीव्ड बगने खहरेकोतररकोतरको महाटरी णदी निरन्तरपटन्

# %%
predict_from_speech(test_audio_ip3)
# Out:
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  2.1097e-02,
#           2.3051e-02,  2.5386e-02],
#         [-1.1921e-07, -1.1921e-07, -1.1921e-07,  ...,  1.3188e-02,
#           1.6076e-02,  1.8417e-02]]) 48000
# Prediction:
# आ्मेले लेखैर आएटाह उला आमना नामहरू एकैसेलमा धाउन लागि्यो अनपनि रलने ैन नआमरा नामहरू एकैचिनपछि हिु धपलियो नेपनि रहने छरैन नामडा नामहरू आमी लोहदालदई नन आमरा नामहरू आमीने दलपछि धन कोसरी लकला  नामडानामहरूआमीे लेैरा आएकातहौ िमा आमनाननामह
